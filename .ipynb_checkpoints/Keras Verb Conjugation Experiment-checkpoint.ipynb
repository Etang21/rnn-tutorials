# %% [markdown]
# An implementation of sequence to sequence learning for performing addition
# Input: "535+61"
# Output: "596"
# Padding is handled by using a repeated sentinel character (space)
# Input may optionally be reversed, shown to increase performance in many tasks in:
# "Learning to Execute"
# http://arxiv.org/abs/1410.4615
# and
# "Sequence to Sequence Learning with Neural Networks"
# http://papers.nips.cc/paper/5346-sequence-to-sequence-learning-with-neural-networks.pdf
# Theoretically it introduces shorter term dependencies between source and target.
#
# Modified to train RNN to conjugate past tense of verbs. Data currently taken from UCLA dataset on verb conjugation.
#
# Code taken, modified from https://github.com/keras-team/keras/blob/master/examples/addition_rnn.py

# %%
from __future__ import print_function
from keras.models import Sequential
from keras import layers
import numpy as np
from six.moves import range
import csv
from keras.regularizers import L1L2

# %% [markdown]
# ## Character Table
#
# Taking in our string of numbers/operations as a string of characters, we must vectorize each character as a new input to our RNN.
#
# We first create a table mapping each character in our vocabulary (in our case, this is the numbers 0-9 and addition symbol '+') to a unique integer index. We also create a table mapping back the other way.
#
# To encode a string, we convert each character in the string to a one-hot vector with the character index as 1 and all other indices as 0. We also feed in the parameter `num_rows` as a maximum length of our string, equivalent to padding all strings to a specified length.
#
# To decode an output array x, we take each vector of the string (representing a component) and decode it back into its most likely character. NOTE: I'm a little unclear about how we deal with variable-length answers. Maybe those are just decoded into space characters?

# %%
class CharacterTable(object):
    """Given a set of characters:
    + Encode them to a one hot integer representation
    + Decode the one hot integer representation to their character output
    + Decode a vector of probabilities to their character output
    """
    def __init__(self, chars):
        """Initialize character table.
        # Arguments
            chars: Characters that can appear in the input.
        """
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))

    def encode(self, C, num_rows):
        """One hot encode given string C.
        # Arguments
            num_rows: Number of rows in the returned one hot encoding. This is
                used to keep the # of rows for each data the same.
        """
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x

    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in x)

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %% [markdown]
# ## Model Parameters
#
# These parameters are now heuristically chosen based on the data in our database.
#
# MAXLEN is the maximum length of any one input (or can be truncated below that). Chosen as 14, for max input length from UCLA dataset.
# TRAINING_SIZE is an approximation (I think) for the number of examples in our dataset.
# `chars` is a string with all characters that can be used in our inputs/outputs. We also add a space for padding.
#
# REVERSE is not currently used, but it should indicate whether we feed the inputs in standard order or reversed.

# %%
# Parameters for the model and dataset.
TRAINING_SIZE = 50000
MAXLEN_INPUT = 14
MAXLEN_OUTPUT = 15
REVERSE = True

chars = 'abcdefghijklmnopqrstuvwxyz '
ctable = CharacterTable(chars)

# %% [markdown]
# ## Data Processing for Verb Tenses
#
# We read in the data from our CSV of UCLA's verb tenses. Then we vectorize them using the Character class and model parameters defined above.

# %%
data_file = 'ucla-verb-tenses.csv'

import re # For stripping non-alphanumeric characters
present = []
past = []
with open(data_file) as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        if not (re.search(r'\W+', row[0]) or re.search(r'\W+', row[1])):
            # Only add if all alphanumeric
            # Then pad inputs with spaces
            present_word = row[0] + ' ' * (MAXLEN_INPUT - len(row[0]))
            if REVERSE:
                # Reverse the query, e.g., '12+345  ' becomes '  543+21'.
                present_word = present_word[::-1]
            present.append(present_word)
            past_word = row[1] + ' ' * (MAXLEN_OUTPUT - len(row[1]))
            past.append(past_word)

print(list(zip(present, past))[:10])
print("MAXLEN of input: ", max([len(s) for s in present]))
print("MAXLEN of output: ", max([len(s) for s in past]))

assert(len(present)==len(past))
print("Num examples: ", len(present))
# Out:
# [('abet          ', 'abetted        '), ('abide         ', 'abided         '), ('abolish       ', 'abolished      '), ('abound        ', 'abounded       '), ('absent        ', 'absented       '), ('absorb        ', 'absorbed       '), ('abstract      ', 'abstracted     '), ('abuse         ', 'abused         '), ('accelerate    ', 'accelerated    '), ('accept        ', 'accepted       ')]
# MAXLEN of input:  14
# MAXLEN of output:  15
# Num examples:  2144

# %% [markdown]
# ## Data Processing
#
# Vectorize data using the Character library and previously set parameters

# %%
print('Vectorization...')
x = np.zeros((len(past), MAXLEN_INPUT, len(chars)), dtype=np.bool)
y = np.zeros((len(past), MAXLEN_OUTPUT, len(chars)), dtype=np.bool)
for i, word in enumerate(present):
    x[i] = ctable.encode(word, MAXLEN_INPUT)
for i, word in enumerate(past):
    y[i] = ctable.encode(word, MAXLEN_OUTPUT)

# Shuffle (x, y) in unison as the later parts of x will almost all be larger
# digits.
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# Explicitly set apart 10% for validation data that we never train over.
split_at = len(x) - len(x) // 10
(x_train, x_val) = x[:split_at], x[split_at:]
(y_train, y_val) = y[:split_at], y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)
# Out:
# Vectorization...
# Training Data:
# (1930, 14, 27)
# (1930, 15, 27)
# Validation Data:
# (214, 14, 27)
# (214, 15, 27)

# %% [markdown]
# ## Setting up Model

# %%
# Try replacing GRU, or SimpleRNN.
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 3


print('Build model...')
model = Sequential()
# "Encode" the input sequence using an RNN, producing an output of HIDDEN_SIZE.
# Note: In a situation where your input sequences have a variable length,
# use input_shape=(None, num_feature).
model.add(RNN(HIDDEN_SIZE, input_shape=(MAXLEN_INPUT, len(chars))))
# As the decoder RNN's input, repeatedly provide with the last hidden state of
# RNN for each time step. Repeat 'DIGITS + 1' times as that's the maximum
# length of output, e.g., when DIGITS=3, max output is 999+999=1998.
model.add(layers.RepeatVector(MAXLEN_OUTPUT))
# The decoder RNN could be multiple layers stacked or a single layer.
for _ in range(LAYERS):
    # By setting return_sequences to True, return not only the last output but
    # all the outputs so far in the form of (num_samples, timesteps,
    # output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    model.add(RNN(HIDDEN_SIZE, return_sequences=True))

# Apply a dense layer to the every temporal slice of an input. For each of step
# of the output sequence, decide which character should be chosen.
model.add(layers.TimeDistributed(layers.Dense(len(chars))))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_19 (LSTM)               (None, 128)               79872
# _________________________________________________________________
# repeat_vector_9 (RepeatVecto (None, 15, 128)           0
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 15, 128)           131584
# _________________________________________________________________
# lstm_21 (LSTM)               (None, 15, 128)           131584
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 15, 128)           131584
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 15, 27)            3483
# _________________________________________________________________
# activation_9 (Activation)    (None, 15, 27)            0
# =================================================================
# Total params: 478,107
# Trainable params: 478,107
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training, Validating Model

# %%
# Print validation examples and classifications from the dataset
def classify_val_examples():
    # Select 10 samples from the validation set at random so we can visualize
    # errors.
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)

# %%
# Train the model each generation and show predictions against the validation
# dataset. Also graph the loss and validation loss.

loss = []
val_loss = []
for iteration in range(1, 500):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    history = model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    classify_val_examples()
    print('LOSS: ', history.history['loss'])
    print('VAL LOSS: ', history.history['val_loss'])
    loss.append(history.history['loss'])
    val_loss.append(history.history['val_loss'])
    
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()
# Out:
# --------------------------------------------------
# Iteration 1
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 5s 3ms/step - loss: 2.4630 - acc: 0.4626 - val_loss: 1.7574 - val_acc: 0.5012
# Q conspire       T conspired       ☒
# Q prolong        T prolonged       ☒
# Q assault        T assaulted       ☒
# Q formulate      T formulated      ☒
# Q plunge         T plunged         ☒
# Q reclaim        T reclaimed       ☒
# Q drag           T dragged         ☒
# Q act            T acted           ☒
# Q thicken        T thickened       ☒
# Q belt           T belted          ☒
#
# --------------------------------------------------
# Iteration 2
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.7215 - acc: 0.4943 - val_loss: 1.6116 - val_acc: 0.5012
# Q clip           T clipped         ☒
# Q clip           T clipped         ☒
# Q telegraph      T telegraphed     ☒
# Q preclude       T precluded       ☒
# Q thicken        T thickened       ☒
# Q talk           T talked          ☒
# Q curve          T curved          ☒
# Q buckle         T buckled         ☒
# Q understand     T understood      ☒
# Q generalize     T generalized     ☒
#
# --------------------------------------------------
# Iteration 3
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.5749 - acc: 0.5231 - val_loss: 1.4997 - val_acc: 0.5483
# Q load           T loaded          ☒ eeeee
# Q congratulate   T congratulated   ☒ eeeeerabjjjjjjj
# Q hope           T hoped           ☒ eeeee
# Q obsess         T obsessed        ☒ eeeee
# Q perform        T performed       ☒ eeeeee
# Q wag            T wagged          ☒ eeeee
# Q pick           T picked          ☒ eeeee
# Q lapse          T lapsed          ☒ eeeee
# Q flower         T flowered        ☒ eeeee
# Q pose           T posed           ☒ eeeee
#
# --------------------------------------------------
# Iteration 4
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.4785 - acc: 0.5609 - val_loss: 1.4175 - val_acc: 0.5754
# Q dock           T docked          ☒ eeeeed
# Q waver          T wavered         ☒ eeeeee
# Q behold         T beheld          ☒ eeeeeed
# Q establish      T established     ☒ eeeeeeeeed
# Q swish          T swished         ☒ eeeeeed
# Q load           T loaded          ☒ eeeeed
# Q clutter        T cluttered       ☒ eeeeeeed
# Q conduct        T conducted       ☒ eeeeeeed
# Q scramble       T scrambled       ☒ eeeeeeee
# Q depart         T departed        ☒ eeeeeed
#
# --------------------------------------------------
# Iteration 5
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.3986 - acc: 0.5923 - val_loss: 1.3392 - val_acc: 0.6047
# Q like           T liked           ☒ eeeed
# Q tax            T taxed           ☒ eeeed
# Q lapse          T lapsed          ☒ eeeeed
# Q stagger        T staggered       ☒ eeeeeeed
# Q ponder         T pondered        ☒ eeeeeed
# Q extend         T extended        ☒ eeeeeed
# Q curse          T cursed          ☒ eeeeee
# Q finish         T finished        ☒ eeeeeeed
# Q read           T read            ☒ eeeed
# Q purport        T purported       ☒ eeeeeeeed
#
# --------------------------------------------------
# Iteration 6
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.3585 - acc: 0.5954 - val_loss: 1.3585 - val_acc: 0.5869
# Q owe            T owed            ☒ eeeed
# Q center         T centered        ☒ reeeeeed
# Q clarify        T clarified       ☒ reeeeeeeed
# Q ponder         T pondered        ☒ reeeeeed
# Q waver          T wavered         ☒ reeeeed
# Q wheel          T wheeled         ☒ eeeeeed
# Q wheel          T wheeled         ☒ eeeeeed
# Q choke          T choked          ☒ reeeeed
# Q head           T headed          ☒ eeeeed
# Q return         T returned        ☒ reeeeeedd
#
# --------------------------------------------------
# Iteration 7
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.3307 - acc: 0.6003 - val_loss: 1.2849 - val_acc: 0.6271
# Q formulate      T formulated      ☒ rrrrreeeed
# Q stagger        T staggered       ☒ rrreeeed
# Q stay           T stayed          ☒ reeeed
# Q tax            T taxed           ☒ reeed
# Q overshadow     T overshadowed    ☒ rrrrreeeeed
# Q repay          T repayed         ☒ rreeeed
# Q people         T peopled         ☒ rreeeed
# Q cherish        T cherished       ☒ rrreeeeed
# Q want           T wanted          ☒ reeeed
# Q croon          T crooned         ☒ rreeeed
#
# --------------------------------------------------
# Iteration 8
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2887 - acc: 0.6174 - val_loss: 1.2877 - val_acc: 0.6044
# Q understand     T understood      ☒ rrrrrrrtted
# Q congratulate   T congratulated   ☒ rrrrrrrrtteed
# Q exemplify      T exemplified     ☒ rrrrrrtteed
# Q reclaim        T reclaimed       ☒ rrrrreed
# Q tumble         T tumbled         ☒ rrreeed
# Q tax            T taxed           ☒ reeed
# Q understand     T understood      ☒ rrrrrrrtted
# Q hope           T hoped           ☒ reeed
# Q gaze           T gazed           ☒ reeed
# Q curve          T curved          ☒ rreeed
#
# --------------------------------------------------
# Iteration 9
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2707 - acc: 0.6147 - val_loss: 1.2529 - val_acc: 0.6231
# Q recommend      T recommended     ☒ rrrraiited
# Q skim           T skimmed         ☒ rreeed
# Q swish          T swished         ☒ rrreeed
# Q jam            T jammed          ☒ rreed
# Q darn           T darned          ☒ rrreed
# Q reclaim        T reclaimed       ☒ rrrrrted
# Q scramble       T scrambled       ☒ rrrraited
# Q bar            T barred          ☒ rreed
# Q protect        T protected       ☒ rrrrrteed
# Q preclude       T precluded       ☒ rrrrrteed
#
# --------------------------------------------------
# Iteration 10
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.2543 - acc: 0.6198 - val_loss: 1.2448 - val_acc: 0.6171
# Q pinch          T pinched         ☒ roaaeed
# Q ignite         T ignited         ☒ roaaeed
# Q consolidate    T consolidated    ☒ aroaaaaited
# Q assault        T assaulted       ☒ rooaatedd
# Q explore        T explored        ☒ rooaated
# Q mar            T mared           ☒ rreed
# Q blossom        T blossomed       ☒ rooaateed
# Q govern         T governed        ☒ roaateed
# Q act            T acted           ☒ rreed
# Q lean           T leaned          ☒ rreeed
#
# --------------------------------------------------
# Iteration 11
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.2467 - acc: 0.6206 - val_loss: 1.2238 - val_acc: 0.6305
# Q formulate      T formulated      ☒ rooaaitted
# Q accuse         T accused         ☒ roareed
# Q wag            T wagged          ☒ reeed
# Q owe            T owed            ☒ reee
# Q originate      T originated      ☒ rooaaitted
# Q gloat          T gloated         ☒ roareed
# Q acquaint       T acquainted      ☒ rooaaitted
# Q assault        T assaulted       ☒ rooaateed
# Q acquaint       T acquainted      ☒ rooaaitted
# Q root           T rooted          ☒ rreeed
#
# --------------------------------------------------
# Iteration 12
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2504 - acc: 0.6147 - val_loss: 1.2170 - val_acc: 0.6287
# Q rid            T rid             ☒ oreed
# Q flag           T flaged          ☒ ooreed
# Q fell           T felled          ☒ ooreed
# Q understand     T understood      ☒ rrooaaaitted
# Q quit           T quit            ☒ ooaeed
# Q labor          T labored         ☒ ooaaeed
# Q allot          T allotted        ☒ ooaaeed
# Q combat         T combated        ☒ roaaaeed
# Q labor          T labored         ☒ ooaaeed
# Q clutter        T cluttered       ☒ rooaateed
#
# --------------------------------------------------
# Iteration 13
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2244 - acc: 0.6270 - val_loss: 1.2121 - val_acc: 0.6321
# Q salvage        T salvaged        ☒ oooaieed
# Q compress       T compressed      ☒ rooaaiited
# Q dock           T docked          ☒ ooeeed
# Q fell           T felled          ☒ ooeeed
# Q thicken        T thickened       ☒ oooaiteed
# Q protect        T protected       ☒ oooaiieed
# Q overshadow     T overshadowed    ☒ roooaiiitted
# Q rebut          T rebutted        ☒ ooaieed
# Q wince          T winced          ☒ ooaeed
# Q thicken        T thickened       ☒ oooaiteed
#
# --------------------------------------------------
# Iteration 14
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2192 - acc: 0.6293 - val_loss: 1.2441 - val_acc: 0.6090
# Q mislead        T misled          ☒ oooareed
# Q rally          T rallied         ☒ ooareed
# Q date           T dated           ☒ oeeed
# Q appraise       T appraised       ☒ oooaateed
# Q discern        T discerned       ☒ oooaateed
# Q curve          T curved          ☒ ooreed
# Q rule           T ruled           ☒ oeeed
# Q lean           T leaned          ☒ ooeee
# Q fumble         T fumbled         ☒ oooreed
# Q distinguish    T distinguished   ☒ roooaaaiiteed
#
# --------------------------------------------------
# Iteration 15
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2274 - acc: 0.6217 - val_loss: 1.2007 - val_acc: 0.6324
# Q forget         T forgot          ☒ roaated
# Q solve          T solved          ☒ ooreed
# Q endorse        T endorsed        ☒ rooaited
# Q dock           T docked          ☒ ooeeed
# Q distinguish    T distinguished   ☒ rrrraaiiitted
# Q thicken        T thickened       ☒ rooaited
# Q stagger        T staggered       ☒ rooaiteed
# Q cherish        T cherished       ☒ rooaiited
# Q discern        T discerned       ☒ rooaaited
# Q repay          T repayed         ☒ ooareed
#
# --------------------------------------------------
# Iteration 16
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2040 - acc: 0.6345 - val_loss: 1.2154 - val_acc: 0.6181
# Q exced          T exceeded        ☒ ooeeed
# Q chew           T chewed          ☒ ooeee
# Q radiate        T radiated        ☒ oooateed
# Q prolong        T prolonged       ☒ rooaiteed
# Q explore        T explored        ☒ oooaited
# Q simmer         T simmered        ☒ oooateed
# Q mean           T meant           ☒ ooeeed
# Q climb          T climbed         ☒ ooaited
# Q repay          T repayed         ☒ ooareed
# Q cherish        T cherished       ☒ rooaitted
#
# --------------------------------------------------
# Iteration 17
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.2034 - acc: 0.6324 - val_loss: 1.1974 - val_acc: 0.6265
# Q climb          T climbed         ☒ ooareed
# Q sponsor        T sponsored       ☒ rooaaited
# Q repay          T repayed         ☒ ooareed
# Q vanish         T vanished        ☒ oooareed
# Q fell           T felled          ☒ ooeeed
# Q pack           T packed          ☒ ooeeed
# Q rule           T ruled           ☒ oeeed
# Q roam           T roamed          ☒ ooreed
# Q owe            T owed            ☒ eeeed
# Q cherish        T cherished       ☒ rooaaited
#
# --------------------------------------------------
# Iteration 18
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1945 - acc: 0.6352 - val_loss: 1.1801 - val_acc: 0.6393
# Q return         T returned        ☒ rooaited
# Q tax            T taxed           ☒ oeeed
# Q discern        T discerned       ☒ rooaiited
# Q jam            T jammed          ☒ oeeed
# Q curtail        T curtailed       ☒ rooaiited
# Q finish         T finished        ☒ oooaited
# Q double         T doubled         ☒ oooated
# Q waver          T wavered         ☒ ooareed
# Q assault        T assaulted       ☒ rooaiited
# Q quarrel        T quarreled       ☒ rooaiteed
#
# --------------------------------------------------
# Iteration 19
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1850 - acc: 0.6373 - val_loss: 1.1970 - val_acc: 0.6349
# Q protect        T protected       ☒ rooaiited
# Q transcend      T transcended     ☒ roooaiitted
# Q crack          T cracked         ☒ oooited
# Q eradicate      T eradicated      ☒ rooaiiited
# Q assault        T assaulted       ☒ rooaiited
# Q lighten        T lightened       ☒ rooaiited
# Q skim           T skimmed         ☒ ooated
# Q rally          T rallied         ☒ oooited
# Q brag           T bragged         ☒ ooated
# Q survey         T surveyed        ☒ oooaited
#
# --------------------------------------------------
# Iteration 20
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1943 - acc: 0.6356 - val_loss: 1.1785 - val_acc: 0.6480
# Q carve          T carved          ☒ eoated
# Q clip           T clipped         ☒ eoatee
# Q scrawl         T scrawled        ☒ eooaited
# Q visit          T visited         ☒ eoaated
# Q originate      T originated      ☒ reeaaiited
# Q telegraph      T telegraphed     ☒ reeeaiiited
# Q protect        T protected       ☒ rooaiited
# Q rename         T renamed         ☒ eoaated
# Q load           T loaded          ☒ eoeeed
# Q eradicate      T eradicated      ☒ reeaaiited
#
# --------------------------------------------------
# Iteration 21
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1789 - acc: 0.6457 - val_loss: 1.1798 - val_acc: 0.6436
# Q rebut          T rebutted        ☒ eoaated
# Q shift          T shifted         ☒ eoaated
# Q laugh          T laughed         ☒ eoaated
# Q kick           T kicked          ☒ eoaeed
# Q flutter        T fluttered       ☒ eeeaaited
# Q center         T centered        ☒ eeaaited
# Q scrawl         T scrawled        ☒ eeaaited
# Q originate      T originated      ☒ reeaaaited
# Q understand     T understood      ☒ seeeaaaaated
# Q date           T dated           ☒ eoeed
#
# --------------------------------------------------
# Iteration 22
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1807 - acc: 0.6411 - val_loss: 1.2216 - val_acc: 0.6209
# Q repair         T repaired        ☒ eeeaiteed
# Q flutter        T fluttered       ☒ eeeaaited
# Q tax            T taxed           ☒ eoleed
# Q croon          T crooned         ☒ eeaateed
# Q finish         T finished        ☒ eeeaited
# Q roll           T rolled          ☒ eoaleed
# Q adhere         T adhered         ☒ eeaated
# Q crack          T cracked         ☒ eeaated
# Q carve          T carved          ☒ eoaleed
# Q frame          T framed          ☒ eoaleed
#
# --------------------------------------------------
# Iteration 23
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1952 - acc: 0.6354 - val_loss: 1.1656 - val_acc: 0.6523
# Q hope           T hoped           ☒ eolee
# Q labor          T labored         ☒ eeaated
# Q root           T rooted          ☒ eoated
# Q labor          T labored         ☒ eeaated
# Q croon          T crooned         ☒ eeaated
# Q effect         T effected        ☒ eeeaited
# Q vanish         T vanished        ☒ eeeaited
# Q mar            T mared           ☒ eoled
# Q stay           T stayed          ☒ eoated
# Q skim           T skimmed         ☒ eoated
#
# --------------------------------------------------
# Iteration 24
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1735 - acc: 0.6452 - val_loss: 1.1596 - val_acc: 0.6498
# Q scramble       T scrambled       ☒ eeeeaited
# Q formulate      T formulated      ☒ eeeeaaited
# Q trace          T traced          ☒ eoated
# Q predict        T predicted       ☒ eeeeaited
# Q lean           T leaned          ☒ eoated
# Q unscrew        T unscrewed       ☒ eeeaateed
# Q lighten        T lightened       ☒ eeeaaited
# Q vanish         T vanished        ☒ eeeaited
# Q establish      T established     ☒ eeeeeaatted
# Q bulge          T bulged          ☒ eoated
#
# --------------------------------------------------
# Iteration 25
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1731 - acc: 0.6463 - val_loss: 1.1527 - val_acc: 0.6514
# Q bestow         T bestowed        ☒ eeeaited
# Q visit          T visited         ☒ eeaited
# Q choke          T choked          ☒ eoated
# Q drag           T dragged         ☒ eoated
# Q pinch          T pinched         ☒ eeaited
# Q unscrew        T unscrewed       ☒ eeeaiteed
# Q absent         T absented        ☒ eeeaited
# Q skim           T skimmed         ☒ eoated
# Q curse          T cursed          ☒ eoated
# Q clarify        T clarified       ☒ eeeeiited
#
# --------------------------------------------------
# Iteration 26
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1689 - acc: 0.6469 - val_loss: 1.1528 - val_acc: 0.6495
# Q pledge         T pledged         ☒ eoaated
# Q down           T downed          ☒ eoated
# Q allot          T allotted        ☒ eoaated
# Q cover          T covered         ☒ eoaated
# Q head           T headed          ☒ eoled
# Q purport        T purported       ☒ eeeeaited
# Q brag           T bragged         ☒ eoated
# Q recommend      T recommended     ☒ seeeeaatted
# Q purport        T purported       ☒ eeeeaited
# Q vanish         T vanished        ☒ eeeaited
#
# --------------------------------------------------
# Iteration 27
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1589 - acc: 0.6502 - val_loss: 1.1537 - val_acc: 0.6520
# Q gloat          T gloated         ☒ eeaited
# Q abound         T abounded        ☒ eeeaited
# Q ride           T rode            ☒ eoeed
# Q wire           T wired           ☒ eoled
# Q understand     T understood      ☒ seeeeeiiated
# Q absent         T absented        ☒ eeeaited
# Q stay           T stayed          ☒ eoated
# Q sponsor        T sponsored       ☒ eeeeiited
# Q draft          T drafted         ☒ eeeited
# Q transcend      T transcended     ☒ seeeeiiited
#
# --------------------------------------------------
# Iteration 28
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1559 - acc: 0.6503 - val_loss: 1.1432 - val_acc: 0.6542
# Q drift          T drifted         ☒ eeaated
# Q pledge         T pledged         ☒ eeaated
# Q cover          T covered         ☒ eeaated
# Q date           T dated           ☒ eated
# Q appraise       T appraised       ☒ eeeeiited
# Q generalize     T generalized     ☒ seeeeeiated
# Q rename         T renamed         ☒ eeaated
# Q enslave        T enslaved        ☒ eeeaited
# Q retort         T retorted        ☒ eeeaited
# Q belt           T belted          ☒ eoated
#
# --------------------------------------------------
# Iteration 29
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1512 - acc: 0.6519 - val_loss: 1.1444 - val_acc: 0.6533
# Q bar            T barred          ☒ ealeed
# Q pile           T piled           ☒ eated
# Q clip           T clipped         ☒ eoaleed
# Q read           T read            ☒ ealed
# Q misinterpret   T misinterpreted  ☒ seeeeeeeiatted
# Q pinch          T pinched         ☒ eeaited
# Q protrude       T protruded       ☒ eeeeiited
# Q streak         T streaked        ☒ eeeaieed
# Q outweigh       T outweighed      ☒ eeeeeiited
# Q owe            T owed            ☒ eeed
#
# --------------------------------------------------
# Iteration 30
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1460 - acc: 0.6530 - val_loss: 1.1597 - val_acc: 0.6492
# Q view           T viewed          ☒ eated
# Q balance        T balanced        ☒ eeeaited
# Q acquaint       T acquainted      ☒ eeeeeiated
# Q repair         T repaired        ☒ eeeeited
# Q gape           T gaped           ☒ eated
# Q draft          T drafted         ☒ eeaited
# Q ride           T rode            ☒ eaeed
# Q visit          T visited         ☒ eeaated
# Q wheel          T wheeled         ☒ eoated
# Q coordinate     T coordinated     ☒ seeeeiiated
#
# --------------------------------------------------
# Iteration 31
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1832 - acc: 0.6376 - val_loss: 1.2573 - val_acc: 0.6100
# Q swing          T swung           ☒ eeeated
# Q telegraph      T telegraphed     ☒ seeeeeiateed
# Q marvel         T marveled        ☒ eeeiited
# Q rebut          T rebutted        ☒ eeaated
# Q mislead        T misled          ☒ eeeeiited
# Q defy           T defied          ☒ eoated
# Q simmer         T simmered        ☒ eeeeited
# Q pledge         T pledged         ☒ eeaated
# Q ponder         T pondered        ☒ eeeeited
# Q endorse        T endorsed        ☒ eeeeireed
#
# --------------------------------------------------
# Iteration 32
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1743 - acc: 0.6441 - val_loss: 1.1412 - val_acc: 0.6555
# Q climb          T climbed         ☒ eeoated
# Q retort         T retorted        ☒ eeeeited
# Q vanish         T vanished        ☒ eeeeited
# Q allot          T allotted        ☒ eooated
# Q appraise       T appraised       ☒ eeeeiated
# Q radiate        T radiated        ☒ eeeeited
# Q learn          T learned         ☒ eeoated
# Q seek           T sought          ☒ eated
# Q enslave        T enslaved        ☒ eeeeited
# Q gloat          T gloated         ☒ eooated
#
# --------------------------------------------------
# Iteration 33
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1440 - acc: 0.6524 - val_loss: 1.1458 - val_acc: 0.6511
# Q eradicate      T eradicated      ☒ seeeeiited
# Q rebut          T rebutted        ☒ eooated
# Q jam            T jammed          ☒ oated
# Q recommend      T recommended     ☒ seeeeeitted
# Q effect         T effected        ☒ eeeeited
# Q forget         T forgot          ☒ eeeiree
# Q finish         T finished        ☒ eeeeited
# Q exemplify      T exemplified     ☒ seeeeeiated
# Q rock           T rocked          ☒ eoated
# Q telegraph      T telegraphed     ☒ seeeeeiated
#
# --------------------------------------------------
# Iteration 34
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1409 - acc: 0.6561 - val_loss: 1.1321 - val_acc: 0.6558
# Q consolidate    T consolidated    ☒ seeeeeeaated
# Q exemplify      T exemplified     ☒ seeeeeiated
# Q talk           T talked          ☒ eaated
# Q hint           T hinted          ☒ eoated
# Q clarify        T clarified       ☒ seeeeated
# Q lighten        T lightened       ☒ seeeeated
# Q ride           T rode            ☒ eated
# Q unscrew        T unscrewed       ☒ eeeeiited
# Q recede         T receded         ☒ eoaleed
# Q cover          T covered         ☒ eeaated
#
# --------------------------------------------------
# Iteration 35
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1387 - acc: 0.6558 - val_loss: 1.1352 - val_acc: 0.6533
# Q draft          T drafted         ☒ eeaated
# Q carry          T carried         ☒ eeeated
# Q allot          T allotted        ☒ eeaated
# Q pose           T posed           ☒ eaned
# Q simmer         T simmered        ☒ eeeeited
# Q purport        T purported       ☒ seeeeated
# Q ride           T rode            ☒ eated
# Q swish          T swished         ☒ eeaated
# Q maintain       T maintained      ☒ seeeeiated
# Q scrawl         T scrawled        ☒ eeeeited
#
# --------------------------------------------------
# Iteration 36
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1394 - acc: 0.6571 - val_loss: 1.1281 - val_acc: 0.6561
# Q eradicate      T eradicated      ☒ seeeeiated
# Q suspect        T suspected       ☒ seeeiited
# Q overshadow     T overshadowed    ☒ seeeeeiaated
# Q misinterpret   T misinterpreted  ☒ seeeeeeeaated
# Q tumble         T tumbled         ☒ eeaated
# Q belie          T belied          ☒ eaated
# Q crack          T cracked         ☒ eoaited
# Q misuse         T misused         ☒ eeaated
# Q quit           T quit            ☒ eaated
# Q part           T parted          ☒ eaated
#
# --------------------------------------------------
# Iteration 37
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1308 - acc: 0.6595 - val_loss: 1.1504 - val_acc: 0.6548
# Q down           T downed          ☒ eaaled
# Q shiver         T shivered        ☒ seeeired
# Q tumble         T tumbled         ☒ eeeated
# Q perfect        T perfected       ☒ seeeeited
# Q hint           T hinted          ☒ eaaled
# Q reclaim        T reclaimed       ☒ seeeeited
# Q perfect        T perfected       ☒ seeeeited
# Q rename         T renamed         ☒ eeeared
# Q mislead        T misled          ☒ seeeeited
# Q mislead        T misled          ☒ seeeeited
#
# --------------------------------------------------
# Iteration 38
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1365 - acc: 0.6566 - val_loss: 1.1232 - val_acc: 0.6564
# Q formulate      T formulated      ☒ seeeeiated
# Q seek           T sought          ☒ eated
# Q predict        T predicted       ☒ seeeeated
# Q scrawl         T scrawled        ☒ seeeated
# Q ponder         T pondered        ☒ seeeated
# Q originate      T originated      ☒ seeeeiated
# Q ignite         T ignited         ☒ eeaated
# Q sting          T stung           ☒ seeared
# Q head           T headed          ☒ eaned
# Q wire           T wired           ☒ eated
#
# --------------------------------------------------
# Iteration 39
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1275 - acc: 0.6599 - val_loss: 1.1642 - val_acc: 0.6452
# Q distinguish    T distinguished   ☒ seeeeeeiiated
# Q maintain       T maintained      ☒ seeeeeited
# Q cover          T covered         ☒ seeired
# Q reclaim        T reclaimed       ☒ seeeeited
# Q defy           T defied          ☒ eoaleed
# Q pledge         T pledged         ☒ seeiree
# Q act            T acted           ☒ aaneed
# Q transplant     T transplanted    ☒ seeeeeeiated
# Q marvel         T marveled        ☒ seeeited
# Q flutter        T fluttered       ☒ seeeeited
#
# --------------------------------------------------
# Iteration 40
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1440 - acc: 0.6534 - val_loss: 1.1579 - val_acc: 0.6483
# Q belt           T belted          ☒ eaated
# Q cover          T covered         ☒ eeaited
# Q pinch          T pinched         ☒ eoaited
# Q establish      T established     ☒ seeeeeated
# Q repay          T repayed         ☒ eeaated
# Q repay          T repayed         ☒ eeaated
# Q clip           T clipped         ☒ eaated
# Q dock           T docked          ☒ eaated
# Q drift          T drifted         ☒ eoaited
# Q gape           T gaped           ☒ aated
#
# --------------------------------------------------
# Iteration 41
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1345 - acc: 0.6586 - val_loss: 1.1192 - val_acc: 0.6617
# Q laugh          T laughed         ☒ eoaited
# Q extend         T extended        ☒ seeeited
# Q pick           T picked          ☒ eaated
# Q ride           T rode            ☒ aated
# Q allot          T allotted        ☒ eoaited
# Q raise          T raised          ☒ eaated
# Q laugh          T laughed         ☒ eoaited
# Q congratulate   T congratulated   ☒ seeeeeeiatted
# Q gloat          T gloated         ☒ eoaited
# Q buckle         T buckled         ☒ eeaited
#
# --------------------------------------------------
# Iteration 42
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1334 - acc: 0.6570 - val_loss: 1.1405 - val_acc: 0.6564
# Q wheel          T wheeled         ☒ eeaited
# Q murmur         T murmured        ☒ seeeited
# Q blossom        T blossomed       ☒ seeeeated
# Q clip           T clipped         ☒ eoaited
# Q mislead        T misled          ☒ seeeeated
# Q flower         T flowered        ☒ seeeited
# Q double         T doubled         ☒ eeeated
# Q generalize     T generalized     ☒ seeeeeiated
# Q tax            T taxed           ☒ aated
# Q want           T wanted          ☒ eaated
#
# --------------------------------------------------
# Iteration 43
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.2824 - acc: 0.6056 - val_loss: 1.2003 - val_acc: 0.6078
# Q conspire       T conspired       ☒ seeeeate
# Q hope           T hoped           ☒ aanee
# Q while          T whiled          ☒ eaate
# Q clip           T clipped         ☒ eoante
# Q guard          T guarded         ☒ soaite
# Q rid            T rid             ☒ aane
# Q suspect        T suspected       ☒ seeeiite
# Q tick           T ticked          ☒ eaate
# Q perfect        T perfected       ☒ seeeiite
# Q waver          T wavered         ☒ soaite
#
# --------------------------------------------------
# Iteration 44
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1933 - acc: 0.6356 - val_loss: 1.1620 - val_acc: 0.6467
# Q flower         T flowered        ☒ seeeited
# Q gloat          T gloated         ☒ soaited
# Q lapse          T lapsed          ☒ eaated
# Q flutter        T fluttered       ☒ seeeiated
# Q blossom        T blossomed       ☒ seeeeated
# Q root           T rooted          ☒ eaated
# Q behold         T beheld          ☒ seeeiee
# Q wag            T wagged          ☒ aated
# Q recommend      T recommended     ☒ seeeeeaated
# Q conduct        T conducted       ☒ seeeiated
#
# --------------------------------------------------
# Iteration 45
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1468 - acc: 0.6564 - val_loss: 1.1258 - val_acc: 0.6620
# Q guard          T guarded         ☒ soaited
# Q recommend      T recommended     ☒ serrrriated
# Q adore          T adored          ☒ saated
# Q head           T headed          ☒ aaled
# Q rock           T rocked          ☒ eaated
# Q need           T needed          ☒ aated
# Q assault        T assaulted       ☒ serriited
# Q guard          T guarded         ☒ soaited
# Q gaze           T gazed           ☒ aated
# Q descend        T descended       ☒ serreated
#
# --------------------------------------------------
# Iteration 46
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1361 - acc: 0.6612 - val_loss: 1.1245 - val_acc: 0.6604
# Q discern        T discerned       ☒ seeeeated
# Q roam           T roamed          ☒ eaated
# Q understand     T understood      ☒ seeeeeeaated
# Q finish         T finished        ☒ seeeited
# Q rotate         T rotated         ☒ seaated
# Q laugh          T laughed         ☒ soaited
# Q hint           T hinted          ☒ eaated
# Q sponsor        T sponsored       ☒ seeeeated
# Q choke          T choked          ☒ eaated
# Q flank          T flanked         ☒ soaited
#
# --------------------------------------------------
# Iteration 47
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1233 - acc: 0.6628 - val_loss: 1.1150 - val_acc: 0.6592
# Q wince          T winced          ☒ eaated
# Q sting          T stung           ☒ sooited
# Q emit           T emitted         ☒ eaated
# Q precede        T preceded        ☒ seeerted
# Q learn          T learned         ☒ seoited
# Q rally          T rallied         ☒ soaited
# Q radiate        T radiated        ☒ seeeited
# Q wire           T wired           ☒ aated
# Q while          T whiled          ☒ eaated
# Q quit           T quit            ☒ eaated
#
# --------------------------------------------------
# Iteration 48
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1170 - acc: 0.6646 - val_loss: 1.1121 - val_acc: 0.6604
# Q hint           T hinted          ☒ eaated
# Q eradicate      T eradicated      ☒ seeeeeated
# Q birdie         T birdied         ☒ searted
# Q drag           T dragged         ☒ saaled
# Q wheel          T wheeled         ☒ seerted
# Q birdie         T birdied         ☒ searted
# Q generalize     T generalized     ☒ seeeeeiated
# Q swish          T swished         ☒ soanted
# Q kick           T kicked          ☒ eaated
# Q balance        T balanced        ☒ seeeited
#
# --------------------------------------------------
# Iteration 49
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1179 - acc: 0.6634 - val_loss: 1.1046 - val_acc: 0.6604
# Q repair         T repaired        ☒ seeeited
# Q ride           T rode            ☒ aated
# Q fumble         T fumbled         ☒ soaited
# Q rule           T ruled           ☒ aated
# Q conduct        T conducted       ☒ seeeeated
# Q repay          T repayed         ☒ soaated
# Q buckle         T buckled         ☒ seaited
# Q laugh          T laughed         ☒ soaited
# Q appraise       T appraised       ☒ seeeeated
# Q clip           T clipped         ☒ saaneed
#
# --------------------------------------------------
# Iteration 50
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1126 - acc: 0.6658 - val_loss: 1.1003 - val_acc: 0.6645
# Q belt           T belted          ☒ saated
# Q absent         T absented        ☒ seeeited
# Q consume        T consumed        ☒ seeeated
# Q weep           T wept            ☒ earted
# Q owe            T owed            ☒ aeed
# Q drag           T dragged         ☒ saaned
# Q swing          T swung           ☒ sooined
# Q gloat          T gloated         ☒ soaited
# Q hint           T hinted          ☒ saated
# Q seek           T sought          ☒ eated
#
# --------------------------------------------------
# Iteration 51
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1055 - acc: 0.6686 - val_loss: 1.1029 - val_acc: 0.6698
# Q perform        T performed       ☒ seeeeared
# Q rally          T rallied         ☒ soaited
# Q govern         T governed        ☒ seeeired
# Q recede         T receded         ☒ seeeted
# Q choke          T choked          ☒ saated
# Q misuse         T misused         ☒ seeared
# Q elude          T eluded          ☒ saated
# Q slice          T sliced          ☒ saated
# Q root           T rooted          ☒ saated
# Q rid            T rid             ☒ aated
#
# --------------------------------------------------
# Iteration 52
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.1020 - acc: 0.6708 - val_loss: 1.1181 - val_acc: 0.6645
# Q jam            T jammed          ☒ aaned
# Q guard          T guarded         ☒ saaneed
# Q while          T whiled          ☒ saated
# Q read           T read            ☒ eaned
# Q combat         T combated        ☒ soointed
# Q curtail        T curtailed       ☒ sereeited
# Q ransack        T ransacked       ☒ sereinted
# Q quit           T quit            ☒ aaiked
# Q retort         T retorted        ☒ serented
# Q recede         T receded         ☒ seeeted
#
# --------------------------------------------------
# Iteration 53
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1112 - acc: 0.6702 - val_loss: 1.1035 - val_acc: 0.6645
# Q protrude       T protruded       ☒ sereeated
# Q satisfy        T satisfied       ☒ sereeated
# Q shift          T shifted         ☒ soaited
# Q fumble         T fumbled         ☒ soaited
# Q purport        T purported       ☒ sereeited
# Q read           T read            ☒ eared
# Q explore        T explored        ☒ sereated
# Q wire           T wired           ☒ aated
# Q rid            T rid             ☒ aated
# Q telegraph      T telegraphed     ☒ seeeeeaaed
#
# --------------------------------------------------
# Iteration 54
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1010 - acc: 0.6706 - val_loss: 1.0859 - val_acc: 0.6710
# Q consume        T consumed        ☒ sereated
# Q dock           T docked          ☒ aaiked
# Q reclaim        T reclaimed       ☒ sereiited
# Q kick           T kicked          ☒ aaiked
# Q abound         T abounded        ☒ sooineed
# Q curtail        T curtailed       ☒ sereiited
# Q scramble       T scrambled       ☒ sereeated
# Q balance        T balanced        ☒ seriited
# Q satisfy        T satisfied       ☒ sereeated
# Q view           T viewed          ☒ saated
#
# --------------------------------------------------
# Iteration 55
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.0896 - acc: 0.6768 - val_loss: 1.0791 - val_acc: 0.6794
# Q date           T dated           ☒ eated
# Q raise          T raised          ☒ saated
# Q croon          T crooned         ☒ sooined
# Q precede        T preceded        ☒ seeeeted
# Q sponsor        T sponsored       ☒ serreined
# Q darn           T darned          ☒ saoned
# Q delay          T delayed         ☒ sooared
# Q assault        T assaulted       ☒ sereeited
# Q repair         T repaired        ☒ sereined
# Q endorse        T endorsed        ☒ seeeered
#
# --------------------------------------------------
# Iteration 56
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.0815 - acc: 0.6806 - val_loss: 1.0767 - val_acc: 0.6782
# Q rule           T ruled           ☒ eated
# Q down           T downed          ☒ saoned
# Q establish      T established     ☒ seeeeeiited
# Q simmer         T simmered        ☒ sereired
# Q pack           T packed          ☒ aaiked
# Q view           T viewed          ☒ saated
# Q murmur         T murmured        ☒ sooiined
# Q originate      T originated      ☒ seeeeiated
# Q gape           T gaped           ☒ aaned
# Q criticize      T criticized      ☒ seeeeiated
#
# --------------------------------------------------
# Iteration 57
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.0696 - acc: 0.6832 - val_loss: 1.0716 - val_acc: 0.6785
# Q depart         T departed        ☒ seeerted
# Q curve          T curved          ☒ saated
# Q trace          T traced          ☒ seated
# Q congratulate   T congratulated   ☒ seeetttiaated
# Q mar            T mared           ☒ aaped
# Q swing          T swung           ☒ soonped
# Q hear           T heard           ☒ seered
# Q ransack        T ransacked       ☒ seriiited
# Q postpone       T postponed       ☒ sereeired
# Q pinch          T pinched         ☒ soonped
#
# --------------------------------------------------
# Iteration 58
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.0587 - acc: 0.6875 - val_loss: 1.0584 - val_acc: 0.6829
# Q rally          T rallied         ☒ sooined
# Q exemplify      T exemplified     ☒ seereiiined
# Q climb          T climbed         ☒ sooineed
# Q overshadow     T overshadowed    ☒ seeeeeiiined
# Q owe            T owed            ☒ aeed
# Q salvage        T salvaged        ☒ seriined
# Q effect         T effected        ☒ seeested
# Q endorse        T endorsed        ☒ seeeated
# Q wag            T wagged          ☒ aaned
# Q congratulate   T congratulated   ☒ seeettttiated
#
# --------------------------------------------------
# Iteration 59
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.0467 - acc: 0.6891 - val_loss: 1.0481 - val_acc: 0.6810
# Q distinguish    T distinguished   ☒ seeeeeeeiited
# Q exced          T exceeded        ☒ seated
# Q sting          T stung           ☒ sooined
# Q mislead        T misled          ☒ sereaited
# Q misuse         T misused         ☒ seeered
# Q curse          T cursed          ☒ seated
# Q wag            T wagged          ☒ aaned
# Q lean           T leaned          ☒ saaled
# Q satisfy        T satisfied       ☒ sereianed
# Q strain         T strained        ☒ sroiined
#
# --------------------------------------------------
# Iteration 60
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.0357 - acc: 0.6911 - val_loss: 1.0368 - val_acc: 0.6838
# Q drift          T drifted         ☒ soaated
# Q root           T rooted          ☒ saated
# Q wire           T wired           ☒ aated
# Q tax            T taxed           ☒ aated
# Q frighten       T frightened      ☒ seeeeeered
# Q exced          T exceeded        ☒ seated
# Q pack           T packed          ☒ aanked
# Q cherish        T cherished       ☒ seeeerted
# Q outweigh       T outweighed      ☒ serriiited
# Q need           T needed          ☒ eated
#
# --------------------------------------------------
# Iteration 61
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 1.0281 - acc: 0.6931 - val_loss: 1.3366 - val_acc: 0.5822
# Q hint           T hinted          ☒ sooled
# Q jam            T jammed          ☒ aanped
# Q radiate        T radiated        ☒ settaated
# Q root           T rooted          ☒ saaled
# Q bestow         T bestowed        ☒ serrereed
# Q learn          T learned         ☒ sooinhed
# Q originate      T originated      ☒ sertiiated
# Q govern         T governed        ☒ srrrerhed
# Q rid            T rid             ☒ aaned
# Q transplant     T transplanted    ☒ seettiiiined
#
# --------------------------------------------------
# Iteration 62
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 1.1413 - acc: 0.6527 - val_loss: 1.1193 - val_acc: 0.6489
# Q postpone       T postponed       ☒ seriiined
# Q assault        T assaulted       ☒ settaaed
# Q transcend      T transcended     ☒ seetiiined
# Q transcend      T transcended     ☒ seetiiined
# Q sponsor        T sponsored       ☒ sereiined
# Q matriculate    T matriculated    ☒ seetttiaaedd
# Q defy           T defied          ☒ saated
# Q brag           T bragged         ☒ sanned
# Q part           T parted          ☒ saated
# ...
# Q drift          T drifted         ☒ diiited
# Q transplant     T transplanted    ☒ srrrrrranted
# Q congratulate   T congratulated   ☒ conlaatuuated
# Q wind           T winded          ☒ wiund
# Q conduct        T conducted       ☒ confucted
#
# --------------------------------------------------
# Iteration 308
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1686 - acc: 0.9566 - val_loss: 0.5508 - val_acc: 0.8417
# Q skim           T skimmed         ☒ shimmed
# Q rock           T rocked          ☑ rocked
# Q curse          T cursed          ☒ cersed
# Q head           T headed          ☒ heeded
# Q cover          T covered         ☑ covered
# Q return         T returned        ☒ resarned
# Q pile           T piled           ☑ piled
# Q flower         T flowered        ☒ foofered
# Q like           T liked           ☒ lixed
# Q govern         T governed        ☒ defrimed
#
# --------------------------------------------------
# Iteration 309
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1665 - acc: 0.9580 - val_loss: 0.5512 - val_acc: 0.8436
# Q telegraph      T telegraphed     ☒ deeeararhed
# Q guard          T guarded         ☒ ghauded
# Q load           T loaded          ☒ lolded
# Q behold         T beheld          ☒ bebeld
# Q fell           T felled          ☒ fell
# Q satisfy        T satisfied       ☒ ssssified
# Q talk           T talked          ☑ talked
# Q survey         T surveyed        ☒ seeeeied
# Q lapse          T lapsed          ☒ laased
# Q pile           T piled           ☑ piled
#
# --------------------------------------------------
# Iteration 310
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1628 - acc: 0.9593 - val_loss: 0.5691 - val_acc: 0.8436
# Q quarrel        T quarreled       ☒ drrhhaled
# Q enslave        T enslaved        ☒ eeloaved
# Q down           T downed          ☒ lorned
# Q generalize     T generalized     ☒ detoralized
# Q originate      T originated      ☒ intiinated
# Q sweep          T swept           ☒ seeered
# Q drag           T dragged         ☒ drageed
# Q rule           T ruled           ☒ prled
# Q birdie         T birdied         ☒ iitided
# Q croon          T crooned         ☒ ccooned
#
# --------------------------------------------------
# Iteration 311
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1628 - acc: 0.9576 - val_loss: 0.5643 - val_acc: 0.8424
# Q endorse        T endorsed        ☒ envorted
# Q darn           T darned          ☑ darned
# Q fell           T felled          ☒ fell
# Q center         T centered        ☒ cnntered
# Q need           T needed          ☒ eed
# Q head           T headed          ☒ heeddd
# Q quarrel        T quarreled       ☒ drahhaled
# Q solve          T solved          ☒ sooved
# Q people         T peopled         ☒ peppled
# Q chew           T chewed          ☒ heemed
#
# --------------------------------------------------
# Iteration 312
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 0.3232 - acc: 0.9154 - val_loss: 0.8661 - val_acc: 0.7735
# Q drift          T drifted         ☒ diiited
# Q head           T headed          ☒ cead
# Q compress       T compressed      ☑ compressed
# Q pinch          T pinched         ☒ riiched
# Q buckle         T buckled         ☒ uuspled
# Q coordinate     T coordinated     ☒ conmppnazed
# Q rid            T rid             ☒ rided
# Q need           T needed          ☒ ned
# Q effect         T effected        ☒ fefected
# Q rebut          T rebutted        ☒ mmmiteed
#
# --------------------------------------------------
# Iteration 313
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 0.5249 - acc: 0.8371 - val_loss: 0.6454 - val_acc: 0.8100
# Q part           T parted          ☒ ported
# Q forget         T forgot          ☒ forgive
# Q kick           T kicked          ☒ licked
# Q distinguish    T distinguished   ☒ pipooiimished
# Q mar            T mared           ☒ marred
# Q forget         T forgot          ☒ forgive
# Q unscrew        T unscrewed       ☒ dusrrew
# Q perform        T performed       ☒ pefformed
# Q darn           T darned          ☒ daaned
# Q exemplify      T exemplified     ☒ exponifiied
#
# --------------------------------------------------
# Iteration 314
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 0.3360 - acc: 0.8914 - val_loss: 0.5597 - val_acc: 0.8364
# Q admire         T admired         ☒ detured
# Q explore        T explored        ☑ explored
# Q center         T centered        ☒ cnnterre
# Q while          T whiled          ☑ whiled
# Q hope           T hoped           ☒ hored
# Q croon          T crooned         ☒ ccooned
# Q carve          T carved          ☒ caaxed
# Q suspect        T suspected       ☒ suepected
# Q brag           T bragged         ☒ brabged
# Q pack           T packed          ☑ packed
#
# --------------------------------------------------
# Iteration 315
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.2500 - acc: 0.9233 - val_loss: 0.5418 - val_acc: 0.8374
# Q tick           T ticked          ☑ ticked
# Q belie          T belied          ☒ beeyed
# Q discern        T discerned       ☒ desserne
# Q matriculate    T matriculated    ☒ aasicuulated
# Q outweigh       T outweighed      ☒ bonihened
# Q absent         T absented        ☒ memented
# Q while          T whiled          ☒ hhiled
# Q curse          T cursed          ☒ ceus d
# Q stagger        T staggered       ☒ stamgered
# Q ignite         T ignited         ☒ uimited
#
# --------------------------------------------------
# Iteration 316
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 3s 1ms/step - loss: 0.2033 - acc: 0.9408 - val_loss: 0.5384 - val_acc: 0.8464
# Q buckle         T buckled         ☒ guupled
# Q labor          T labored         ☒ blloped
# Q bestow         T bestowed        ☒ wrtrew
# Q roll           T rolled          ☑ rolled
# Q postpone       T postponed       ☒ prooponed
# Q swish          T swished         ☑ swished
# Q establish      T established     ☒ praarlushed
# Q survey         T surveyed        ☒ seeeeyed
# Q solve          T solved          ☒ sooved
# Q transplant     T transplanted    ☒ srrprrranted
#
# --------------------------------------------------
# Iteration 317
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1796 - acc: 0.9517 - val_loss: 0.5217 - val_acc: 0.8486
# Q formulate      T formulated      ☒ folpulated
# Q ride           T rode            ☒ ridee
# Q accuse         T accused         ☑ accused
# Q satisfy        T satisfied       ☒ ssssified
# Q skim           T skimmed         ☒ skimed
# Q cherish        T cherished       ☒ deddished
# Q telegraph      T telegraphed     ☒ dreerlarhed
# Q solve          T solved          ☒ pooved
# Q predict        T predicted       ☒ prolicted
# Q misinterpret   T misinterpreted  ☒ disinppppesedd
#
# --------------------------------------------------
# Iteration 318
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1666 - acc: 0.9556 - val_loss: 0.5136 - val_acc: 0.8551
# Q repay          T repayed         ☒ rppoyed
# Q compress       T compressed      ☑ compressed
# Q establish      T established     ☒ praarbished
# Q swing          T swung           ☑ swung
# Q ponder         T pondered        ☒ rindered
# Q partake        T partook         ☒ aaraaced
# Q predict        T predicted       ☒ prplicted
# Q correct        T corrected       ☒ corcected
# Q adhere         T adhered         ☒ aatered
# Q lighten        T lightened       ☒ wuighened
#
# --------------------------------------------------
# Iteration 319
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1589 - acc: 0.9593 - val_loss: 0.5019 - val_acc: 0.8508
# Q part           T parted          ☑ parted
# Q admire         T admired         ☒ mmtured
# Q balance        T balanced        ☒ alaanced
# Q tax            T taxed           ☒ tated
# Q strain         T strained        ☑ strained
# Q carry          T carried         ☒ cvcried
# Q postpone       T postponed       ☒ propponed
# Q visit          T visited         ☒ iiiited
# Q view           T viewed          ☒ drew
# Q depart         T departed        ☒ eelasted
#
# --------------------------------------------------
# Iteration 320
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1527 - acc: 0.9615 - val_loss: 0.5284 - val_acc: 0.8483
# Q protrude       T protruded       ☒ prstaided
# Q pack           T packed          ☑ packed
# Q solve          T solved          ☒ ploved
# Q hope           T hoped           ☑ hoped
# Q tax            T taxed           ☒ tated
# Q mean           T meant           ☒ mmened
# Q frame          T framed          ☒ faamed
# Q cover          T covered         ☑ covered
# Q pack           T packed          ☑ packed
# Q gaze           T gazed           ☑ gazed
#
# --------------------------------------------------
# Iteration 321
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1482 - acc: 0.9630 - val_loss: 0.5200 - val_acc: 0.8539
# Q head           T headed          ☒ headdd
# Q carve          T carved          ☒ cerved
# Q crack          T cracked         ☒ cvacked
# Q consume        T consumed        ☒ coccumed
# Q mean           T meant           ☒ emmned
# Q wince          T winced          ☒ winked
# Q wince          T winced          ☒ winked
# Q like           T liked           ☑ liked
# Q jam            T jammed          ☑ jammed
# Q accuse         T accused         ☑ accused
#
# --------------------------------------------------
# Iteration 322
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1451 - acc: 0.9646 - val_loss: 0.5211 - val_acc: 0.8492
# Q govern         T governed        ☒ berrimed
# Q finish         T finished        ☒ fnnished
# Q slice          T sliced          ☑ sliced
# Q weep           T wept            ☒ wepped
# Q overshadow     T overshadowed    ☒ dorrrshrarded
# Q perform        T performed       ☒ reeformed
# Q protect        T protected       ☒ prrructed
# Q choke          T choked          ☑ choked
# Q tax            T taxed           ☒ tated
# Q sweep          T swept           ☒ seert
#
# --------------------------------------------------
# Iteration 323
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1404 - acc: 0.9661 - val_loss: 0.5374 - val_acc: 0.8492
# Q buckle         T buckled         ☒ uuupled
# Q flag           T flaged          ☑ flaged
# Q eradicate      T eradicated      ☒ eecrccated
# Q guard          T guarded         ☒ ghauded
# Q ponder         T pondered        ☒ rindered
# Q balance        T balanced        ☒ alaanced
# Q sweep          T swept           ☒ seert
# Q partake        T partook         ☒ paraaced
# Q pick           T picked          ☑ picked
# Q mar            T mared           ☒ mapred
#
# --------------------------------------------------
# Iteration 324
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1359 - acc: 0.9672 - val_loss: 0.5204 - val_acc: 0.8505
# Q sweep          T swept           ☒ sherte
# Q rotate         T rotated         ☒ rrrated
# Q swish          T swished         ☑ swished
# Q thicken        T thickened       ☒ tiiseened
# Q satisfy        T satisfied       ☒ ssssified
# Q mar            T mared           ☒ marred
# Q curtail        T curtailed       ☒ cascailed
# Q view           T viewed          ☒ drew
# Q curtail        T curtailed       ☒ cascailed
# Q tumble         T tumbled         ☒ tumgled
#
# --------------------------------------------------
# Iteration 325
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1341 - acc: 0.9682 - val_loss: 0.5213 - val_acc: 0.8489
# Q sweep          T swept           ☒ seert
# Q compress       T compressed      ☑ compressed
# Q exemplify      T exemplified     ☒ exponpified
# Q transcend      T transcended     ☒ shreehende
# Q pack           T packed          ☑ packed
# Q frighten       T frightened      ☒ fligthened
# Q repair         T repaired        ☒ reeoired
# Q perform        T performed       ☒ reeformed
# Q thicken        T thickened       ☒ tiiseened
# Q wind           T winded          ☒ wound
#
# --------------------------------------------------
# Iteration 326
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1300 - acc: 0.9687 - val_loss: 0.5262 - val_acc: 0.8483
# Q rid            T rid             ☒ rided
# Q clip           T clipped         ☑ clipped
# Q visit          T visited         ☒ iiiited
# Q unscrew        T unscrewed       ☒ descren
# Q guard          T guarded         ☒ ghauded
# Q talk           T talked          ☑ talked
# Q admire         T admired         ☒ matumed
# Q raise          T raised          ☒ roised
# Q ring           T rang            ☒ ranged
# Q assault        T assaulted       ☒ assllited
#
# --------------------------------------------------
# Iteration 327
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1930/1930 [==============================] - 2s 1ms/step - loss: 0.1269 - acc: 0.9707 - val_loss: 0.5232 - val_acc: 0.8517
# Q endorse        T endorsed        ☒ envorted
# Q gape           T gaped           ☒ baped
# Q gloat          T gloated         ☒ blloted
# Q croon          T crooned         ☒ ccooned
# Q partake        T partook         ☒ paaraued
# Q perfect        T perfected       ☒ pecjected
# Q plunge         T plunged         ☑ plunged
# Q choke          T choked          ☑ choked
# Q sponsor        T sponsored       ☒ sroopered
# Q transport      T transported     ☒ trottrorted
#
# --------------------------------------------------
# Iteration 328
# Train on 1930 samples, validate on 214 samples
# Epoch 1/1
# 1664/1930 [========================>.....] - ETA: 0s - loss: 0.1241 - acc: 0.9725

# %% [markdown]
# ## Assessing Underfitting, Overfitting
#
# Here we plot the model's results to diagnose underfitting or overfitting.
#
# We'll plot the learning curves with training loss and validation loss to understand what happens. Machine Learning Yearning might help us understand this too.

# %%
# %matplotlib inline
from matplotlib import pyplot

history = model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=600,
              validation_data=(x_val, y_val))
# plot train and validation loss
pyplot.plot(history.history['loss'])
pyplot.plot(history.history['val_loss'])
pyplot.title('model train vs validation loss')
pyplot.ylabel('loss')
pyplot.xlabel('epoch')
pyplot.legend(['train', 'validation'], loc='upper right')
pyplot.show()
# Out:
# Train on 1930 samples, validate on 214 samples
# Epoch 1/600
# 1930/1930 [==============================] - 3s 2ms/step - loss: 16.2367 - acc: 0.4288 - val_loss: 13.1607 - val_acc: 0.5012
# Epoch 2/600
# 1930/1930 [==============================] - 1s 615us/step - loss: 11.3721 - acc: 0.4943 - val_loss: 9.2820 - val_acc: 0.5012
# Epoch 3/600
# 1930/1930 [==============================] - 1s 660us/step - loss: 7.9315 - acc: 0.5038 - val_loss: 6.3251 - val_acc: 0.5274
# Epoch 4/600
# 1930/1930 [==============================] - 1s 617us/step - loss: 5.3043 - acc: 0.5392 - val_loss: 4.1224 - val_acc: 0.5757
# Epoch 5/600
# 1930/1930 [==============================] - 1s 667us/step - loss: 3.4177 - acc: 0.5678 - val_loss: 2.6190 - val_acc: 0.5732
# Epoch 6/600
# 1930/1930 [==============================] - 1s 621us/step - loss: 2.2065 - acc: 0.5794 - val_loss: 1.7840 - val_acc: 0.5819
# Epoch 7/600
# 1930/1930 [==============================] - 1s 609us/step - loss: 1.6438 - acc: 0.5798 - val_loss: 1.5287 - val_acc: 0.5869
# Epoch 8/600
# 1930/1930 [==============================] - 1s 605us/step - loss: 1.4950 - acc: 0.5897 - val_loss: 1.4427 - val_acc: 0.5978
# Epoch 9/600
# 1930/1930 [==============================] - 1s 614us/step - loss: 1.4288 - acc: 0.5928 - val_loss: 1.4747 - val_acc: 0.5801
# Epoch 449/600
# 1930/1930 [==============================] - 1s 754us/step - loss: 0.5252 - acc: 0.8597 - val_loss: 0.7947 - val_acc: 0.7869
# Epoch 450/600
# 1930/1930 [==============================] - 1s 740us/step - loss: 0.5210 - acc: 0.8577 - val_loss: 0.8053 - val_acc: 0.7841
# Epoch 451/600
# 1930/1930 [==============================] - 1s 691us/step - loss: 0.5155 - acc: 0.8616 - val_loss: 0.8136 - val_acc: 0.7832
# Epoch 452/600
# 1930/1930 [==============================] - 2s 784us/step - loss: 0.5099 - acc: 0.8628 - val_loss: 0.8196 - val_acc: 0.7779
# Epoch 453/600
# 1930/1930 [==============================] - 1s 756us/step - loss: 0.5136 - acc: 0.8609 - val_loss: 0.8225 - val_acc: 0.7807
# Epoch 454/600
# 1930/1930 [==============================] - 1s 737us/step - loss: 0.5234 - acc: 0.8573 - val_loss: 0.8189 - val_acc: 0.7773
# Epoch 455/600
# 1930/1930 [==============================] - 1s 764us/step - loss: 0.5300 - acc: 0.8568 - val_loss: 0.8209 - val_acc: 0.7763
# Epoch 456/600
# 1930/1930 [==============================] - 2s 795us/step - loss: 0.5197 - acc: 0.8598 - val_loss: 0.8283 - val_acc: 0.7769
# Epoch 457/600
# 1930/1930 [==============================] - 1s 760us/step - loss: 0.5196 - acc: 0.8601 - val_loss: 0.8202 - val_acc: 0.7832
# Epoch 458/600
# 1930/1930 [==============================] - 1s 720us/step - loss: 0.5230 - acc: 0.8589 - val_loss: 0.8604 - val_acc: 0.7645
# Epoch 459/600
# 1930/1930 [==============================] - 1s 679us/step - loss: 0.5472 - acc: 0.8523 - val_loss: 0.8390 - val_acc: 0.7757
# Epoch 460/600
# 1408/1930 [====================>.........] - ETA: 0s - loss: 0.5484 - acc: 0.8500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-37e1f55b888c> in <module>()
#       5               batch_size=BATCH_SIZE,
#       6               epochs=600,
# ----> 7               validation_data=(x_val, y_val))
#       8 # plot train and validation loss
#       9 pyplot.plot(history.history['loss'])
#
# ~/anaconda3/envs/nlu/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1000                               initial_epoch=initial_epoch,
#    1001                               steps_per_epoch=steps_per_epoch,
# -> 1002                               validation_steps=validation_steps)
#    1003
#    1004     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/nlu/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/envs/nlu/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1234                         ins_batch[i] = ins_batch[i].toarray()
#    1235
# -> 1236                     outs = f(ins_batch)
#    1237                     if not isinstance(outs, list):
#    1238                         outs = [outs]
#
# ~/anaconda3/envs/nlu/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
classify_val_examples()
# Out:
# Q down           T downed          ☒ folled
# Q drift          T drifted         ☒ granted
# Q protect        T protected       ☒ crovested
# Q rule           T ruled           ☒ boved
# Q wire           T wired           ☒ faced
# Q quarrel        T quarreled       ☒ oonlbered
# Q read           T read            ☒ reaied
# Q wheel          T wheeled         ☒ fled
# Q mean           T meant           ☒ deaied
# Q establish      T established     ☒ exttaainted
